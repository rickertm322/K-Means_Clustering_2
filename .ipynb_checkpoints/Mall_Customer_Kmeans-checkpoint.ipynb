# %% [markdown]
# # Create Clustering Using K-Means Algorithm On Mall Customers Dataset

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
#pandas: data analysis 
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from scipy.stats import kurtosis,skew
import seaborn as sns
#seaborn: statistical graphing 
from ydata_profiling import ProfileReport
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ## Load Dataset

# %%
df=pd.read_csv('./Mall_Customers.csv')
#calls pandas function 'read_csv' which converts the file into a DataFrame in pandas
#which is a 2d data structure (table, array, etc.)

# %%
df
#Prints out the dataframe
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Dataset Exploration

# %%
df.info()
#pandas.DataFrame.info(): 
#Prints data about the dataframe
#By each column, prints the title of the column, the number of non-null entries in the column
#and the datatype of the column (integer, str, etc.) 
#Also shows the memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
#pandas.DataFrame.isnull() finds the missing values in the dataframe and sends
#them to true, and sends all other values to false. 
#.sum() adds up all the True values of the isnull() command to show the 
#number of empty spots in the dataframe.
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.drop('CustomerID',inplace=True,axis=1)

# %%
df
#pandas.DataFrame.drop removes columns from the dataframe.
#the above command removed the "customerID" column, as the data was repeated 
#from the first column.
# -> Be careful, this can only be ran once- if ran multiple times, it will 
#result in an error, as it will try to remove the same column twice from the
#dataframe.
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df.columns=['Gender','Age','Annual_Income','Spending_Score(1-100)']
#Renames the columns to remove spaces and unnessecary information
#pandas.dataframe.columns updates the labels of the columbs in the dataframe.

# %%
df.describe()
#pandas.dataframe.describe() gives general stats about each column of data. 
#count = # of data points
#mean = mean of the data
#std = standard deviation
#min = minimum value of the data
#25% = 25th percentile of the data
#50% = 50th percentile of the data
#75% = 75th percentile of the data
#max = maximum value of the data
# Out:
#               Age  Annual_Income  Spending_Score(1-100)
# count  200.000000     200.000000             200.000000
# mean    38.850000      60.560000              50.200000
# std     13.969007      26.264721              25.823522
# min     18.000000      15.000000               1.000000
# 25%     28.750000      41.500000              34.750000
# 50%     36.000000      61.500000              50.000000
# 75%     49.000000      78.000000              73.000000
# max     70.000000     137.000000              99.000000

# %%
df.corr(numeric_only = True)
#pandas.dataframe.corr() gives the pairwise correlation of each two columns 
#of the dataframe. Default is the Pearson correlation coefficient (described
#later). Original code did not specify numeric_only, so needed to debug to only
#take into account numeric data. 

#Pearson correlation coefficient (PCC):
#Let cov(x,y) be the covariance of x and y, and stdx, stdy to be the standard
#deviations of x and y respectively. Let p be the PCC
#p = cov(x,y)/(stdx*stdy)
#Covariance represents the tendency of the data to change together (x and y
#have some sort of relation). 
#The PCC is a normalized number which represents the tendency of the data to 
#have a linear correlation. 
# -1<p<0 indicates a negative linear relationship
# p = 0 (or very small) indicates no linear relationship
# 0<p<1 indicates a positive linear relationship
# p values of 1 and -1 indicate perfect linear correlation as well. For most 
#data we expect a value somewhere in between. 

#Analysis of the data below:
#Age and annual income have a low correlation factor, so they likely aren't 
#very relation. However age and spending score have a higher PCC, so we can say
#that as age goes up, generally people spend less. 
#Spending score and annual income also don't seem to have a correlation,
#as the PCC is very low.
# Out:
#                             Age  Annual_Income  Spending_Score(1-100)
# Age                    1.000000      -0.012398              -0.327227
# Annual_Income         -0.012398       1.000000               0.009903
# Spending_Score(1-100) -0.327227       0.009903               1.000000

# %% [markdown]
# ## Data Visualization

# %%
plt.style.use('dark_background')
plt.figure(figsize=(17,8))
sns.heatmap(df.corr(numeric_only = True),annot=True,square=True,cmap='tab10')
#making a heatmap of the above table; annot = True writes the value in each cell
#square = True makes the axes equal so the figure is a square, cmap = tab10 
#is the colormap that the data is measured on. 
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
#plt stuff is just changing the appearance of the plot
plt.savefig('Pairwise Correlation')

# %%
plt.style.use('dark_background')
plt.figure(figsize=(15,10))
sns.pairplot(df)
#seaborn.pairplot takes the dataframe from pandas and shows the pairwise 
#correlation between all datasets. On the diagonal (where the data is compared
#to itself), this instead shows a distribution plot of the data. 
#We can then see that none of the correlations are distinctly linear, but they
#do have some correlation
plt.savefig('PC Data Graph')

# %%
plt.figure(figsize=(10,8))
df.boxplot(grid = False)
#Turned off the grid, since it made it hard to see the data
#Makes a boxplot to show the distribution of the data: box is upper quartile to
#lower quartile, line in the middle is mean. Lines extending from the box show
#the range of the data. No more than 1.5(Q3-Q1) is plotted, all other data pts 
#are outliers, and are plotted as dots.
# Out:
# <Axes: >

# %%
df['Age'].plot.kde()
#Plots the kernel density estimation for age

#Kernel Density Estimation:
    #A non-parametric way to estimate the probability density function of data.
#Non-parametric Estimation: 
    #Does not assume data points belong to an underlying data structure; instead
    # determines the data structure from the underlying data.
#Probability density function:
    #Given a random set of data, this is a function that will predict the
    #probability that any given sample will be that value.
# Out:
# <Axes: ylabel='Density'>

# %%
df['Annual_Income'].plot.kde()
#KDE for annual income
# Out:
# <Axes: ylabel='Density'>

# %%
df['Spending_Score(1-100)'].plot.kde()
#KDE for spending score
# Out:
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Gender',y='Annual_Income',data=df)
#Plots the aggragate or statistical estimate of a variable with the height of
#a rectangle ('Annual income', in this case) with the error in the estimate as 
#lines on each rectangle.
# Out:
# <Axes: xlabel='Gender', ylabel='Annual_Income'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Age',y='Annual_Income',hue='Gender',data=df,s=150,palette='tab10')
#Scatterplot of age vs. annual income, with the colors representing gender. 
#hue = 'Gender' indicates the color of the plot; can be numeric as well.
#s = 150 is the size of the data points
#palette = 'tab10' is a matplotlib color map for hue.
# Out:
# <Axes: xlabel='Age', ylabel='Annual_Income'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='Spending_Score(1-100)',y='Annual_Income',hue='Gender',data=df,s=150,palette='tab10')
#Same as above
# Out:
# <Axes: xlabel='Spending_Score(1-100)', ylabel='Annual_Income'>

# %%
report=ProfileReport(df)
report.to_file('Mall_Customers_Report.html')
#Generates a profile report of the data, saves it to a seperate file. Pretty
# cool.
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Data Labeling

# %%
encoder=LabelBinarizer()
#sklearn.preprocessing.LabelBinarizer() transforms a multi-class labels into a 
#binary system (literally 1, 0) of belonging to a class or not. 
df['Gender']=encoder.fit_transform(df['Gender'])
#Transforms the 'Gender' column into a binary (1,0) classification; 1 = male
#2 = female

#print(df['Gender']) #using to visualize the change in data

# %%
skew(df)
#measures the skew on a set of data; if the data is normally/uniformly 
#distributed, the skew will be ~ 0. A positive skew indicates the data has 
#more weight on the right, and a negative skew indicates the data has more 
#weight on the left. 

#Gender has a higher skew to the right (male), as does age (unsuprising) and
# income. However, spending score has a skew to the left (smaller).
# Out:
# array([ 0.24174689,  0.48191947,  0.31942368, -0.04686531])

# %%
kurtosis(df)
#Measures the kurtosis of the data, or the 'tailedness'. Tailedness is an 
# informal term to describe how much the data stretches beyond the central 
# mass of data within a normally distributed graph. 
#There are multiple interpretations of kurtosis; automatic is Fisher. In this:
    #Normal distribution = 0 kurtosis, typical bell curve looking thing
    #Thin-tailed < 0 kurtosis, has little data outside of center
    #Thick tailed > 0 kurtosis, has lots of data outside of center. 
#For this data, we see the gender has a very small kurtosis (expected, since 
# it is binary). The rest have small kurtosis as well.
# Out:
# array([-1.94155844, -0.68475139, -0.12589283, -0.83595827])

# %% [markdown]
# ## Plot Elbow Method For Choosing Value Of K

# %%
cluster_no=[i for i in range(1,12)]
#Makes an array of integers from 1 to 12
#print(cluster_no)
WCSS=[]
for i in cluster_no:
    cluster=KMeans(init='k-means++',n_clusters=i,random_state=42)
    #K means: n_clusters gives the algorithm a number of clusters and centroids 
    # to start with. init = 'k-means++' chooses initial centroids using the 
    # probability distribution of the data. random_state = 42 gives the random
    # number generation for the centroid initialization. 
    cluster.fit(df)
    #computes the k-means clustering -> finds the best centroids for the 
    # number of centroids
    WCSS.append(cluster.inertia_)
    #Adds to the empty set the inertia of the k-means ->sum of squared distances
    #to the closes centroid, weighted by sample weights (optional)
    # -> Shows how good the centroids are.

# %%
plt.plot(cluster_no,WCSS,marker='o')
plt.xlabel('Cluster Numbers')
plt.ylabel('WCSS')
#Plotting the inertia of the centroids to the number of centroids. 
#As we can see, the inertia is very high at less than 6 centroids, but around 
# 4 centroids, it levels off a bit. 
plt.savefig('Inertia vs # of clusters')

# %% [markdown]
# ## K-Means Model

# %%
cluster=KMeans(init='k-means++',n_clusters=4,random_state=42)
df['Cluster_No']=cluster.fit_predict(df)
#I suppose we decided 4 clusters is best. This adds a column to the graph
# which assigns the data to a cluster (predicts which cluster any piece of data 
# will belong to)

# %%
cluster.cluster_centers_
#Shows the cluster centers; 4 x 4 b/c 4 clusters and 4 parameters of data. 
# So the cluster has to have a center for each parameter.
# Out:
# array([[ 0.37894737, 44.89473684, 48.70526316, 42.63157895],
#        [ 0.46153846, 32.69230769, 86.53846154, 82.12820513],
#        [ 0.5       , 24.82142857, 28.71428571, 74.25      ],
#        [ 0.52631579, 40.39473684, 87.        , 18.63157895]])

# %%
df
#we can compare the predicted cluster of each member to the cluster centers
#to see the data. For participant 0, the cluster assigned was 2 (3rd row). 
#By comparing the data, we can see that this makes sense, as the data values
#are closest to this centroids values.
# Out:
#      Gender  Age  Annual_Income  Spending_Score(1-100)  Cluster_No
# 0         1   19             15                     39           2
# 1         1   21             15                     81           2
# 2         0   20             16                      6           0
# 3         0   23             16                     77           2
# 4         0   31             17                     40           0
# ..      ...  ...            ...                    ...         ...
# 195       0   35            120                     79           1
# 196       0   45            126                     28           3
# 197       1   32            126                     74           1
# 198       1   32            137                     18           3
# 199       1   30            137                     83           1
#
# [200 rows x 5 columns]

# %% [markdown]
# # Visualize Clusters

# %%
# Creating figure
plt.style.use('dark_background')
fig = plt.figure(figsize = (20, 15))
ax = plt.axes(projection ="3d")
# Creating plot
ax.scatter3D(df['Age'][df['Cluster_No']==0], df['Annual_Income'][df['Cluster_No']==0], df['Spending_Score(1-100)'][df['Cluster_No']==0], c = "red", s=150)
ax.scatter3D(df['Age'][df['Cluster_No']==1], df['Annual_Income'][df['Cluster_No']==1], df['Spending_Score(1-100)'][df['Cluster_No']==1], c = "green", s=150)
ax.scatter3D(df['Age'][df['Cluster_No']==2], df['Annual_Income'][df['Cluster_No']==2], df['Spending_Score(1-100)'][df['Cluster_No']==2], c = "yellow", s=150)
ax.scatter3D(df['Age'][df['Cluster_No']==3], df['Annual_Income'][df['Cluster_No']==3], df['Spending_Score(1-100)'][df['Cluster_No']==3], c = "blue", s=150)
ax.view_init(10, 170)
plt.title("3D scatter plot")
plt.show()
plt.savefig('Visualize the clusters')
#A 3d plot to visualize the data. Gender is omitted here b/c it is binary 
# and 4d plots don't exist (obv). We can see each color as a cluster.
# The clusters are not evenly distributed; yellow has much fewer members than 
# green. However, they make sense to be clustered together.

# %% [markdown]
# ## Result Of Each Clustering

# %%
df.groupby('Cluster_No').mean()
#Groups the dataframe by cluster, approximates the data by mean value
# for each column.
# Out:
#               Gender        Age  Annual_Income  Spending_Score(1-100)
# Cluster_No
# 0           0.378947  44.894737      48.705263              42.631579
# 1           0.461538  32.692308      86.538462              82.128205
# 2           0.500000  24.821429      28.714286              74.250000
# 3           0.526316  40.394737      87.000000              18.631579

# %%
df.groupby('Cluster_No').min()
#Same as above, but approximating using the minimum in group.
# Out:
#             Gender  Age  Annual_Income  Spending_Score(1-100)
# Cluster_No
# 0                0   18             16                      3
# 1                0   27             69                     63
# 2                0   18             15                     39
# 3                0   19             70                      1

# %%
df.groupby('Cluster_No').max()
#Same but using maximum
# Out:
#             Gender  Age  Annual_Income  Spending_Score(1-100)
# Cluster_No
# 0                1   70             69                     60
# 1                1   40            137                     97
# 2                1   35             48                     99
# 3                1   59            137                     40

# %%
df.groupby('Cluster_No').std()
#Same but using standard deviation
# Out:
#               Gender        Age  Annual_Income  Spending_Score(1-100)
# Cluster_No
# 0           0.487699  15.341831      14.522817              14.713616
# 1           0.505035   3.728650      16.312485               9.364489
# 2           0.509175   5.571446      10.384665              14.075524
# 3           0.506009  11.376931      16.271348              10.915947
